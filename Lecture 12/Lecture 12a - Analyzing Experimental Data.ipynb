# %% [markdown]
# # <span style="color:darkblue"> Lecture 12a: Analyzing Experiments </span>
#
# <font size = "5">

# %% [markdown]
# # <span style="color:darkblue"> I. Import Libraries </span>

# %%
# The "pandas" library is used for processing datasets
# The "numpy" is for numeric observations and random numbers
# The "matplotlib.pyplot" library is for creating graphs

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# We will "alias" two sublibraries in "statsmodels"
# "statsmodels.formula.api" contains functions to estimate models
# "statsmodels.api" contains general-use statistical options

import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_col

# %% [markdown]
# <font size = "5">
#
# Import data

# %%
dataset = pd.read_stata("data_raw/malawiexperiment.dta")

# %% [markdown]
# # <span style="color:darkblue"> II. Context </span>

# %% [markdown]
# <font size = "5">
#
# Today we will review a paper by Rebecca Dizon-Ross published <br>
# in the American Economic Review (2019).
#
# - In this study, researchers partnered with local schools in Malawi <br>
# - This study evaluated the impacts of information about children’s <br>
#  academic performance on parents’ subsequent investments in their <br>
#   children’s education.
#
#
# https://www.povertyactionlab.org/evaluation/effects-student-performance-information-parental-decision-making-malawi?lang=fr
#
# https://www.nber.org/papers/w24610

# %% [markdown]
# <font size = "5">
#
# Intervention
#
# - Parents in Malawi with low literacy levels had trouble interpreting <br>
# school report cards.Many parents were unaware that their children were <br>
# struggling with school.
# - The intervention altered the way that the schools engaged with <br>
#  parents. It had an impact on reducing the information gaps.

# %% [markdown]
# <font size = "5">
#
# Experimental Design
#
# - Students were assigned to randomly to treatment and control <br>
# with 50% probability
# - The random assignment was done at the household level

# %% [markdown]
# <font size = "5">
#
# Findings

# %% [markdown]
# <img src="figures/treatmenteffects_dizonross.png" alt="drawing" width="650"/>

# %% [markdown]
# <font size = "5">
#
# At baseline (before the intervention)
#
# - The graph on the left shows parental beliefs at baseline
# - Parents of low performing students thought that they were doing <br>
# better than they were. Ideally it should  be along the 45-degree line
# - Similar results for treated and control groups at baseline because <br>
# of randomization
#
# At endline (after the intervention)
#
# - Treated parents had more accurate perceptions of their children's <br>
# performance
# - The treatment effects varied depending on the baseline test scores

# %% [markdown]
# # <span style="color:darkblue"> II. Basic Descriptive Analysis </span>

# %% [markdown]
# <font size = "5">
#
# Total number of children

# %%
len(dataset)
# Out:
# 5268

# %% [markdown]
# <font size = "5">
#
# Total number of households
#
# - 2 children per households

# %%
unique_ids = pd.unique(dataset["hhid"])
len(unique_ids)
# Out:
# 2634

# %% [markdown]
# <font size = "5">
#
# Calculate number of treated and control

# %%
table = pd.crosstab(index = dataset['treat'],columns = "count")
table
# Out:
# col_0      count
# treat
# Control     2654
# Treatment   2614

# %% [markdown]
# # <span style="color:darkblue"> III. Testing Covariate Balance </span>

# %% [markdown]
# <font size = "5">
#
# Subset treated and control observations

# %%
dataset_treated = dataset.query('treat == "Treatment"')
dataset_control = dataset.query('treat == "Control"')

# %% [markdown]
# <font size = "5">
#
# Socio-economic information can be collected at baseline <br>
# (before the experiment)

# %%
variables_scores      = ["ave"]
variables_respondent  = ["lit","primary_resp_fem","age_par1","farmer"]
variables_household   = ["tot_kids","one_par"]
variables_student     = ["std","age","female","attendance_sv"]

# %% [markdown]
# <font size = "5" >
#
# Check that characteristics are similar between treated and control <br>
# at baseline

# %%
# Compute mean and standard deviation for the treated group
display(dataset_treated[variables_respondent].describe().loc[['mean', 'std']])

# Compute mean and standard deviation for the control group
display(dataset_control[variables_respondent].describe().loc[['mean', 'std']])
# Out:
#            lit  primary_resp_fem   age_par1    farmer
# mean  0.675613          0.758990  40.974080  0.460587
# std   0.468235          0.427778  11.290328  0.498541
#            lit  primary_resp_fem   age_par1    farmer
# mean  0.667426          0.773926  40.645455  0.465544
# std   0.471225          0.418366  10.638597  0.498907

# %% [markdown]
# <font size = "5">

# %% [markdown]
# <font size = "5" >
#
# Conduct a formal test of whether the coefficients are similar
#
# - We should expect the coefficient on the treatment variable <br>
# to be non-significant

# %%
reg_model = smf.ols("lit ~ treat ", dataset)
results = reg_model.fit(cov_type= "HC1")

print(summary_col(results,
                  stars = True))
# Out:
# ============================
#                       lit
# ----------------------------
# Intercept          0.6674***
#                    (0.0092)
# treat[T.Treatment] 0.0082
#                    (0.0130)
# R-squared          0.0001
# R-squared Adj.     -0.0001
# ============================
# Standard errors in
# parentheses.
# * p<.1, ** p<.05, ***p<.01

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# <font size = "3">
#
# - Obtain summary statistics for the mean and standard deviation for <br>
# the other sets of baseline variables

# %%
# Write your own code
# Compute mean and standard deviation for the treated group
display(dataset_treated[variables_household].describe().loc[['mean', 'std']])
display(dataset_treated[variables_scores].describe().loc[['mean', 'std']])
display(dataset_treated[variables_student].describe().loc[['mean', 'std']])

# Compute mean and standard deviation for the control group
display(dataset_control[variables_household].describe().loc[['mean', 'std']])
display(dataset_control[variables_scores].describe().loc[['mean', 'std']])
display(dataset_control[variables_student].describe().loc[['mean', 'std']])
# Out:
#       tot_kids   one_par
# mean  5.101760  0.198929
# std   1.708462  0.399271
#             ave
# mean  46.357307
# std   17.530622
#            std        age    female  attendance_sv
# mean  3.723030  11.568383  0.499208       0.913829
# std   1.370438   2.663856  0.500098       0.128672
#       tot_kids   one_par
# mean  5.163527  0.186888
# std   1.764395  0.389895
#             ave
# mean  47.130746
# std   17.448731
#            std        age    female  attendance_sv
# mean  3.718161  11.664694  0.516784       0.915482
# std   1.360581   2.686088  0.499816       0.129110

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# <font size = "3">
#
# - Write a loop that runs different regressions of baseline covariates <br>
# on the treatment variable. This can help you automate the process of <br>
# testing for covariate balance

# %%
# Write your own code
variables_scores      = ["ave"]
variables_respondent  = ["lit","primary_resp_fem","age_par1","farmer"]
variables_household   = ["tot_kids","one_par"]
variables_student     = ["std","age","female","attendance_sv"]

treatment_var = dataset[["ave", "primary_resp_fem", "age_par1", "farmer", "tot_kids", "one_par", "std", "age", "female", "attendance_sv"]]
results = []

for treatv in treatment_var.columns:
    model_reg_treat = smf.ols(f"{treatv} ~ treat", data = dataset)
    res_treat = model_reg_treat.fit(cov_type = "HC1")
    results.append(res_treat)
    results_table = summary_col(results,
                            stars=True)
    print(results_table)
    #results = res_treat.append()
# Out:
# =============================
#                       ave
# -----------------------------
# Intercept          47.1307***
#                    (0.3387)
# treat[T.Treatment] -0.7734
#                    (0.4820)
# R-squared          0.0005
# R-squared Adj.     0.0003
# =============================
# Standard errors in
# parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# ==============================================
#                       ave     primary_resp_fem
# ----------------------------------------------
# Intercept          47.1307*** 0.7739***
#                    (0.3387)   (0.0081)
# treat[T.Treatment] -0.7734    -0.0149
#                    (0.4820)   (0.0117)
# R-squared          0.0005     0.0003
# R-squared Adj.     0.0003     0.0001
# ==============================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =========================================================
#                       ave     primary_resp_fem  age_par1
# ---------------------------------------------------------
# Intercept          47.1307*** 0.7739***        40.6455***
#                    (0.3387)   (0.0081)         (0.2163)
# treat[T.Treatment] -0.7734    -0.0149          0.3286
#                    (0.4820)   (0.0117)         (0.3163)
# R-squared          0.0005     0.0003           0.0002
# R-squared Adj.     0.0003     0.0001           0.0000
# =========================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# ===================================================================
#                       ave     primary_resp_fem  age_par1    farmer
# -------------------------------------------------------------------
# Intercept          47.1307*** 0.7739***        40.6455*** 0.4655***
#                    (0.3387)   (0.0081)         (0.2163)   (0.0098)
# treat[T.Treatment] -0.7734    -0.0149          0.3286     -0.0050
#                    (0.4820)   (0.0117)         (0.3163)   (0.0138)
# R-squared          0.0005     0.0003           0.0002     0.0000
# R-squared Adj.     0.0003     0.0001           0.0000     -0.0002
# ===================================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =============================================================================
#                       ave     primary_resp_fem  age_par1    farmer   tot_kids
# -----------------------------------------------------------------------------
# Intercept          47.1307*** 0.7739***        40.6455*** 0.4655*** 5.1635***
#                    (0.3387)   (0.0081)         (0.2163)   (0.0098)  (0.0342)
# treat[T.Treatment] -0.7734    -0.0149          0.3286     -0.0050   -0.0618
#                    (0.4820)   (0.0117)         (0.3163)   (0.0138)  (0.0478)
# R-squared          0.0005     0.0003           0.0002     0.0000    0.0003
# R-squared Adj.     0.0003     0.0001           0.0000     -0.0002   0.0001
# =============================================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================================================
#                       ave     primary_resp_fem  age_par1    farmer   tot_kids  one_par
# ---------------------------------------------------------------------------------------
# Intercept          47.1307*** 0.7739***        40.6455*** 0.4655*** 5.1635*** 0.1869***
#                    (0.3387)   (0.0081)         (0.2163)   (0.0098)  (0.0342)  (0.0076)
# treat[T.Treatment] -0.7734    -0.0149          0.3286     -0.0050   -0.0618   0.0120
#                    (0.4820)   (0.0117)         (0.3163)   (0.0138)  (0.0478)  (0.0109)
# R-squared          0.0005     0.0003           0.0002     0.0000    0.0003    0.0002
# R-squared Adj.     0.0003     0.0001           0.0000     -0.0002   0.0001    0.0000
# =======================================================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =================================================================================================
#                       ave     primary_resp_fem  age_par1    farmer   tot_kids  one_par     std
# -------------------------------------------------------------------------------------------------
# Intercept          47.1307*** 0.7739***        40.6455*** 0.4655*** 5.1635*** 0.1869*** 3.7182***
#                    (0.3387)   (0.0081)         (0.2163)   (0.0098)  (0.0342)  (0.0076)  (0.0264)
# treat[T.Treatment] -0.7734    -0.0149          0.3286     -0.0050   -0.0618   0.0120    0.0049
#                    (0.4820)   (0.0117)         (0.3163)   (0.0138)  (0.0478)  (0.0109)  (0.0376)
# R-squared          0.0005     0.0003           0.0002     0.0000    0.0003    0.0002    0.0000
# R-squared Adj.     0.0003     0.0001           0.0000     -0.0002   0.0001    0.0000    -0.0002
# =================================================================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# ============================================================================================================
#                       ave     primary_resp_fem  age_par1    farmer   tot_kids  one_par     std       age
# ------------------------------------------------------------------------------------------------------------
# Intercept          47.1307*** 0.7739***        40.6455*** 0.4655*** 5.1635*** 0.1869*** 3.7182*** 11.6647***
#                    (0.3387)   (0.0081)         (0.2163)   (0.0098)  (0.0342)  (0.0076)  (0.0264)  (0.0533)
# treat[T.Treatment] -0.7734    -0.0149          0.3286     -0.0050   -0.0618   0.0120    0.0049    -0.0963
#                    (0.4820)   (0.0117)         (0.3163)   (0.0138)  (0.0478)  (0.0109)  (0.0376)  (0.0755)
# R-squared          0.0005     0.0003           0.0002     0.0000    0.0003    0.0002    0.0000    0.0003
# R-squared Adj.     0.0003     0.0001           0.0000     -0.0002   0.0001    0.0000    -0.0002   0.0001
# ============================================================================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# ======================================================================================================================
#                       ave     primary_resp_fem  age_par1    farmer   tot_kids  one_par     std       age       female
# ----------------------------------------------------------------------------------------------------------------------
# Intercept          47.1307*** 0.7739***        40.6455*** 0.4655*** 5.1635*** 0.1869*** 3.7182*** 11.6647*** 0.5168***
#                    (0.3387)   (0.0081)         (0.2163)   (0.0098)  (0.0342)  (0.0076)  (0.0264)  (0.0533)   (0.0099)
# treat[T.Treatment] -0.7734    -0.0149          0.3286     -0.0050   -0.0618   0.0120    0.0049    -0.0963    -0.0176
#                    (0.4820)   (0.0117)         (0.3163)   (0.0138)  (0.0478)  (0.0109)  (0.0376)  (0.0755)   (0.0140)
# R-squared          0.0005     0.0003           0.0002     0.0000    0.0003    0.0002    0.0000    0.0003     0.0003
# R-squared Adj.     0.0003     0.0001           0.0000     -0.0002   0.0001    0.0000    -0.0002   0.0001     0.0001
# ======================================================================================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# ====================================================================================================================================
#                       ave     primary_resp_fem  age_par1    farmer   tot_kids  one_par     std       age       female  attendance_sv
# ------------------------------------------------------------------------------------------------------------------------------------
# Intercept          47.1307*** 0.7739***        40.6455*** 0.4655*** 5.1635*** 0.1869*** 3.7182*** 11.6647*** 0.5168*** 0.9155***
#                    (0.3387)   (0.0081)         (0.2163)   (0.0098)  (0.0342)  (0.0076)  (0.0264)  (0.0533)   (0.0099)  (0.0025)
# treat[T.Treatment] -0.7734    -0.0149          0.3286     -0.0050   -0.0618   0.0120    0.0049    -0.0963    -0.0176   -0.0017
#                    (0.4820)   (0.0117)         (0.3163)   (0.0138)  (0.0478)  (0.0109)  (0.0376)  (0.0755)   (0.0140)  (0.0036)
# R-squared          0.0005     0.0003           0.0002     0.0000    0.0003    0.0002    0.0000    0.0003     0.0003    0.0000
# R-squared Adj.     0.0003     0.0001           0.0000     -0.0002   0.0001    0.0000    -0.0002   0.0001     0.0001    -0.0002
# ====================================================================================================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %% [markdown]
# # <span style="color:darkblue"> IV. Calculating Average Treatment Effect </span>
#
#
# - Make sure to use robust standard errors

# %% [markdown]
# <font size = "5">
#
# Effect of treatment on endline beliefs

# %%
reg_model = smf.ols("u_ave ~ treat ", dataset)
results = reg_model.fit(cov_type= "HC1")

print(summary_col(results,
                  stars = True))
# Out:
# =============================
#                      u_ave
# -----------------------------
# Intercept          63.5628***
#                    (0.3435)
# treat[T.Treatment] -7.4218***
#                    (0.4988)
# R-squared          0.0406
# R-squared Adj.     0.0404
# =============================
# Standard errors in
# parentheses.
# * p<.1, ** p<.05, ***p<.01

# %% [markdown]
# <font size = "5">
#
# Add baseline covariates

# %%
reg_model = smf.ols("u_ave ~ treat + ave ", dataset)
results = reg_model.fit(cov_type= "HC1")

print(summary_col(results,
                  stars = True))
# Out:
# =============================
#                      u_ave
# -----------------------------
# Intercept          39.6549***
#                    (0.6801)
# treat[T.Treatment] -7.0564***
#                    (0.4325)
# ave                0.5079***
#                    (0.0129)
# R-squared          0.2725
# R-squared Adj.     0.2722
# =============================
# Standard errors in
# parentheses.
# * p<.1, ** p<.05, ***p<.01

# %% [markdown]
# <font size = "5">
#
# Test for heterogeneous effects

# %%
reg_model = smf.ols("u_ave ~ treat + ave + treat*ave", dataset)
results = reg_model.fit(cov_type= "HC1")

print(summary_col(results,
                  stars = True))
# Out:
# ==================================
#                           u_ave
# ----------------------------------
# Intercept              49.1885***
#                        (0.8840)
# treat[T.Treatment]     -25.9979***
#                        (1.2381)
# ave                    0.3054***
#                        (0.0177)
# treat[T.Treatment]:ave 0.4055***
#                        (0.0241)
# R-squared              0.3095
# R-squared Adj.         0.3091
# ==================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# Test for heterogeneous effects using other baseline covariates!

# %%
# Write your own code
reg_model1 = smf.ols("u_ave ~ treat + lit + treat*lit", dataset)
results1 = reg_model1.fit(cov_type= "HC1")

print(summary_col(results1,
                  stars = True))
# Out:
# =================================
#                          u_ave
# ---------------------------------
# Intercept              62.7431***
#                        (0.6669)
# treat[T.Treatment]     -8.5979***
#                        (0.9313)
# lit                    1.2666
#                        (0.7754)
# treat[T.Treatment]:lit 1.6736
#                        (1.1010)
# R-squared              0.0442
# R-squared Adj.         0.0436
# =================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
