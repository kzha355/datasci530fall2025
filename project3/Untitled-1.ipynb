# %%
# Import packages
import requests
import json
import jmespath
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from collections import Counter

# %%
url_sn = "https://api.openalex.org/works?filter=from_publication_date:2000-01-01&search=social%20network&group_by=publication_year"
search_sn = requests.get(url_sn).json()

# %%
import requests

url = "https://api.openalex.org/works"
params = {
    "filter": "concepts.id:C114713312,from_publication_date:2000-01-01",
    "per-page": 200,
    "cursor": "*"
}

results = []
while True:
    resp = requests.get(url, params=params).json()
    results.extend(resp["results"])
    if "next_cursor" not in resp["meta"]:
        break
    params["cursor"] = resp["meta"]["next_cursor"]
