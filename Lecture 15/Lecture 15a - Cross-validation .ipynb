# %% [markdown]
# # <span style="color:darkblue"> Lecture 15a: Cross-Validation
# </span>
#
# <font size = "5">

# %% [markdown]
# # <span style="color:darkblue"> I. Setup Working Environment </span>

# %%
# The "pandas" library is used for processing datasets
# The "numpy" is for numeric observations and random numbers
# The "matplotlib.pyplot" library is for creating graphs

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# We will use the "sklearn" package

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor as DTR
from sklearn import tree
import sklearn.model_selection as skm
from sklearn.ensemble import RandomForestRegressor as RF
from sklearn.model_selection import (cross_validate, KFold, ShuffleSplit)
from ISLP.models import sklearn_sm


# Import StatsModels
import statsmodels.api as sm

# This is used to create data matrices
import patsy

# %% [markdown]
# # <span style="color:darkblue"> II. Mashable Dataset </span>
#
# <font size = "5">
#
# Read "Mashable" data from Lecture 15

# %%
articles_train  = pd.read_csv("data_raw/ArticlesTrain.csv")
articles_test   = pd.read_csv("data_raw/ArticlesTest.csv")

# %% [markdown]
# <font size = "5">
#
# Create features matrix ($X$) and labels/outcomes $(Y)$

# %%
# Extract all columns except "shares" (the outcome)
X_train = articles_train.drop(columns = ["shares"])
X_test  = articles_test.drop(columns = ["shares"])

# Extract shares (the outcome)
y_train = articles_train[["shares"]]
y_test = articles_test[["shares"]]

# %% [markdown]
# # <span style="color:darkblue"> III. Cross-Validation </span>
#
# <font size = "5">
#
# Train model

# %%
tree_model = DTR(max_depth=3,random_state = 0) 
tree_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=3, random_state=0)

# %% [markdown]
# <font size = "5">
#
# Leave-one-out Cross Validation (LOOCV)
#
# - Can be time consuming!

# %%
## COMMENT OUT THE CODE TO RUN

# M = sklearn_sm(sm.OLS)
# X = sm.add_constant(np.array(X_train))
# Y = np.array(y_train)
# cv_results = cross_validate(M, X, Y, cv=X_train.shape[0])
# cv_err = np.mean(cv_results['test_score'])
# cv_err

# %% [markdown]
# <font size = "5">
#
# K-fold cross validation

# %%
cv_error = np.zeros(5)

M = sklearn_sm(sm.OLS)
X = sm.add_constant(np.array(X_train))
Y = np.array(y_train)

cv = KFold(n_splits=10, shuffle=True, random_state=0) # use same splits for each degree

for i, d in enumerate(range(1,6)):
    X = np.power.outer(H, np.arange(d+1))
    M_CV = cross_validate(M, X, Y, cv=cv)
    cv_error[i] = np.mean(M_CV['test_score'])
    
cv_error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 11
#       9 for i, d in enumerate(range(1,6)):
#      10     X = np.power.outer(X, np.arange(d+1))
# ---> 11     M_CV = cross_validate(M, X, Y, cv=cv)
#      12     cv_error[i] = np.mean(M_CV['test_score'])
#      14 cv_error
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
# ...
